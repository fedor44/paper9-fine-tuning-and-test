# %% [markdown]
# <a href="https://colab.research.google.com/github/fedor44/paper9-fine-tuning-and-test/blob/main/Untitled66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

# positive is represented by 0, neutral by 2, and negative by 1 (analyze_sentiment 결과에 맞춤)
# 참고로 financial_phrasebank 는 1(neutral), 2(positive), 0(negative)
#data = pd.read_csv('/content/drive/MyDrive/paper/financial_news_with_sentiment.csv')

# 1(neutral), 2(positive), 0(negative)
data = pd.read_csv('/content/drive/MyDrive/paper/financial_news_700_with_financial_phrasebank_600.csv')
data = data.dropna()
data
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#       Unnamed: 0                                           sentence  label
# 0              0  Jan. 6 -- Ford is struggling in the face of sl...      0
# 1              1  Pharmaceuticals group Orion Corp reported a fa...      0
# 2              2  However , the growth margin slowed down due to...      0
# 3              3  2009 3 February 2010 - Finland-based steel mak...      0
# 4              4  ( ADPnews ) - Feb 3 , 2010 - Finland-based ste...      0
# ...          ...                                                ...    ...
# 1295        1295  Camera patents Corning flexible glass could en...      2
# 1296        1296                        Apple led Q wearables sales      2
# 1297        1297     Tesla capital raise seen road business improve      2
# 1298        1298                       Apple adding  jobs San Diego      2
# ...

# %%
# !pip install transformers evaluate

# %%
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split
from transformers import DataCollatorWithPadding
import evaluate
import numpy as np
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer
import torch

accuracy = evaluate.load("accuracy")

#tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
#model = AutoModelForSequenceClassification.from_pretrained(
#    "ProsusAI/finbert", num_labels=3, # id2label=id2label, label2id=label2id
#)
#tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/paper/model2_3/checkpoint-530")
#model = AutoModelForSequenceClassification.from_pretrained(
#    "/content/drive/MyDrive/paper/model2_3/checkpoint-530", num_labels=3, # id2label=id2label, label2id=label2id
#)

tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/paper/model2_7")
model = AutoModelForSequenceClassification.from_pretrained(
    "/content/drive/MyDrive/paper/model2_7", num_labels=3, # id2label=id2label, label2id=label2id
)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
def preprocess_function(examples):
    #return tokenizer(examples, truncation=True)
    return tokenizer(examples, truncation=True, padding=True, max_length=512)

texts = data["sentence"].to_list()
labels = data["label"].to_list()
text_train, text_test, labels_train, labels_test = train_test_split(
    texts, labels, test_size=0.1, random_state=42,
)
tokenized_text_train = preprocess_function(text_train)
tokenized_text_test = preprocess_function(text_test)

print("train size:", len(labels_train))
print("test size:", len(labels_test))

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# 1(neutral), 2(positive), 0(negative)
id2label = {2: "positive", 1: "neutral", 0: "negative"}
label2id = {"positive": 2, "neutral": 1, "negative": 0}

model.config.id2label = id2label
model.config.label2id = label2id

class BertDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = BertDataset(tokenized_text_train, labels_train)
test_dataset = BertDataset(tokenized_text_test, labels_test)
# Out:
# train size: 1170
# test size: 130

# %%
# !pip install transformers[torch] -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 31.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 40.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.7 MB/s eta 0:00:00
# ...

# %%
"""
https://www.kaggle.com/code/meruvulikith/finbert-fine-tuning
https://www.kaggle.com/code/jetakow/prosusai-finbert-finetuning
# 비교 후 확인 필요

https://github.com/ProsusAI/finBERT
# FinBERT: Financial Sentiment Analysis with BERT 컨피그
config = Config(   data_dir=cl_data_path,
                   bert_model=bertmodel,
                   num_train_epochs=4.0,
                   model_dir=cl_path,
                   max_seq_length = 64,
                   train_batch_size = 32,
                   learning_rate = 2e-5,
                   output_mode='classification',
                   warm_up_proportion=0.2,
                   local_rank=-1,
                   discriminate=True,
                   gradual_unfreeze=True )
"""



training_args = TrainingArguments(
    output_dir="my_awesome_model444",
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    warmup_steps=100,
    num_train_epochs=1,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=False,
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
trainer.train()
model = trainer.model

trainer.save_model('/content/drive/MyDrive/paper/model2_7/prune1')
# Out:
#     <div>
#
#       <progress value='37' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [37/37 14:12, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.256164</td>
#       <td>0.938462</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# 할필요 없을듯
model.save_pretrained("/content/drive/MyDrive/paper/model2")

# %%
# 할필요 없을듯
tokenizer.save_pretrained("/content/drive/MyDrive/paper/model2")
# Out:
# ('/content/drive/MyDrive/paper/model2/tokenizer_config.json',
#  '/content/drive/MyDrive/paper/model2/special_tokens_map.json',
#  '/content/drive/MyDrive/paper/model2/vocab.txt',
#  '/content/drive/MyDrive/paper/model2/added_tokens.json',
#  '/content/drive/MyDrive/paper/model2/tokenizer.json')

# %%
trainer.save_model('/content/drive/MyDrive/paper/model2_6')

# %%
#from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AutoTokenizer, AutoModelForSequenceClassification

from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/paper/model2_7/prune1")
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/paper/model2_7/prune1")

#model = BertForSequenceClassification.from_pretrained("/content/drive/MyDrive/paper/model1")
#tokenizer = BertTokenizer.from_pretrained("/content/drive/MyDrive/paper/model1")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/paper/financial_phrasebank_auditor_sentiment.csv')

sentences = data['sentence']
labels = data['label']

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch

# 뉴스 헤드라인을 토큰화하고 PyTorch 텐서로 변환하는 함수
def encode_headlines(headlines, tokenizer):
  encoded_batch = tokenizer.batch_encode_plus(headlines, padding=True, return_tensors='pt', truncation=True, max_length=512)
  return encoded_batch

# 감성 분석을 수행하는 함수
def analyze_sentiment(headlines):
  encoded_batch = encode_headlines(headlines, tokenizer)
  with torch.no_grad():
      outputs = model(**encoded_batch)
      predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
  return predictions


  # 예측 레이블과 실제 레이블을 저장할 리스트 초기화
y_pred = []
#y_true = [1, 2, 0, 0, 2]
y_true = labels

"""
sentences = [
    "According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .",
    "For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
    "Sales in Finland decreased by 10.5 % in January , while sales outside Finland dropped by 17 % .",
    "Operating profit fell to EUR 35.4 mn from EUR 68.8 mn in 2007 , including vessel sales gain of EUR 12.3 mn .",
    "Both operating profit and turnover for the nine-month period increased , respectively from EUR2 .4 m and EUR43 .8 m , as compared to the corresponding period a year ago ."
]
"""

predictions = []
for sentence in zip(sentences):
  prediction = analyze_sentiment(sentence)  # 긍정, 부정, 중립 순서임

  pred_label_index = torch.argmax(prediction).item()

  y_pred.append(pred_label_index)
  """
  if pred_label_index == 0:
    #y_pred.append('positive')
    y_pred.append(2)
  elif pred_label_index == 1:
    #y_pred.append('negative')
    y_pred.append(0)
  elif pred_label_index == 2:
    #y_pred.append('neutral')
    y_pred.append(1)
    """

# 정밀도, 재현율, F1 점수 및 정확도 계산
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
accuracy = accuracy_score(y_true, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.8768595041322315
# Precision: 0.8852671511657395
# Recall: 0.8768595041322315
# F1 Score: 0.877257296639673

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Negative', 'Neutral', 'Positive'], yticklabels=['Negative', 'Neutral', 'Positive'])
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
